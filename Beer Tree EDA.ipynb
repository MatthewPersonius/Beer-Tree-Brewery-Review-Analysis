# %% [markdown]
# # Beer Tree Brewery Data Storytelling

# %% [markdown]
# #### Speculation: Beers with higher alcohol content will have higher ratings.

# %%
import csv
from datetime import datetime
import requests

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
beers=pd.read_csv("All_Beer_Tree_Untappd.csv")
no_na=no_na.sort_values(by="Rating", ascending=False)

# %%
beers=no_na

# %%
beers['Beer Type'].unique()
# Out:
# array(['Stout - Imperial / Double', 'Sour - Fruited',
#        'IPA - Imperial / Double New England / Hazy', 'IPA - Sour',
#        'IPA - Triple New England / Hazy', 'Stout - Milk / Sweet',
#        'Stout - Coffee', 'Stout - Imperial / Double Milk',
#        'IPA - New England / Hazy', 'IPA - Imperial / Double Milkshake',
#        'IPA - Imperial / Double', 'Pale Ale - New England / Hazy',
#        'Sour - Other', 'Sour - Fruited Berliner Weisse',
#        'IPA - Milkshake', 'Sour - Berliner Weisse', 'Stout - American',
#        'Lager - American', 'Porter - Imperial / Double',
#        'Stout - Russian Imperial', 'Stout - White', 'Hard Seltzer',
#        'Fruit Beer', 'Pilsner - German', 'IPA - American',
#        'Farmhouse Ale - Saison', 'IPA - Session',
#        'Sour - Traditional Gose', 'Wheat Beer - Other', 'Pilsner - Other',
#        'Pumpkin / Yam Beer', 'Table Beer', 'Märzen',
#        'Wheat Beer - American Pale Wheat', 'Pale Ale - American',
# ...

# %%
IPA_Imperial_Double_Milkshake=beers[beers['Beer Type']=='IPA - Imperial / Double Milkshake']

# %%
IPA_Imperial_Double_Milkshake
# Out:
#      Unnamed: 0                            Beer Name  \
# 0             0          Double Pineapple Creamsicle
# 101         101  Double Pineapple Coconut Creamsicle
#
#                              Beer Type  \
# 0    IPA - Imperial / Double Milkshake
# 101  IPA - Imperial / Double Milkshake
#
#                                            Description  ABV%   IBU  Rating  \
# 0    Lactose free milkshake NEIPA that pours a crea...   8.8  N/A     4.20
# 101  Double Pineapple Coconut Creamsicle is a lacto...   8.8  N/A     4.13
#
#      Number of ratings Date Added   IPA
# 0               2512.0   10/03/18  True
# 101              444.0   01/26/19  True

# %%
IPA_New_England_Hazy =beers[beers['Beer Type']=='IPA - New England / Hazy']

# %%
IPA_New_England_Hazy
# Out:
#      Unnamed: 0          Beer Name                 Beer Type  \
# 32           32       Chromosphere  IPA - New England / Hazy
# 100         100        Proper Dose  IPA - New England / Hazy
# 104         104       Acute Angles  IPA - New England / Hazy
# 14           14  Edge of the Earth  IPA - New England / Hazy
# 26           26          Clickbait  IPA - New England / Hazy
# ..          ...                ...                       ...
# 90           90       Broken Trail  IPA - New England / Hazy
# 203         203  Swimming Sideways  IPA - New England / Hazy
# 164         164          Tree Line  IPA - New England / Hazy
# 218         218    Citrus Splatter  IPA - New England / Hazy
# 102         102           Hey Siri  IPA - New England / Hazy
#
#                                            Description  ABV%   IBU  Rating  \
# 32   Chromosphere. The second of the three layers o...   7.3  N/A     4.21
# 100  A wonderful combination of peach, pineapple, a...   7.3  N/A     4.21
# ...

# %%
 IPA_Imperial_Double_New_England_Hazy=beers[beers['Beer Type']=='IPA - Imperial / Double New England / Hazy']

# %%
 IPA_Imperial_Double_New_England_Hazy
# Out:
#      Unnamed: 0                         Beer Name  \
# 124         124  Roots & Trees & Friends & Things
# 151         151                         Year Four
# 76           76                 Wander the Forest
# 35           35                       Carbon Flux
# 30           30                     Over Exposure
# 43           43                       High Summit
# 5             5                        Brain Stew
# 52           52                    Broken Compass
# 205         205     Wet Hopped Welcome To Jamrock
# 27           27                           Skyline
# 62           62                      Super Soaker
# 11           11                   Time To Pretend
# 16           16                         Cultivate
# 82           82                       Heliosphere
# 45           45                     Speed Wobbles
# 58           58                            Canopy
# 40           40                   Save That Money
# 110         110               Fusion of Instincts
# ...

# %%
Stout_Coffee=beers[beers['Beer Type']=='Stout - Coffee']

# %%
Stout_Coffee
# Out:
#      Unnamed: 0                   Beer Name       Beer Type  \
# 63           63    Morning Timber - Vanilla  Stout - Coffee
# 69           69  Morning Timber - Blueberry  Stout - Coffee
# 8             8              Morning Timber  Stout - Coffee
# 157         157                 Tiny Timber  Stout - Coffee
#
#                                            Description ABV%   IBU  Rating  \
# 63   Breakfast Stout brewed with love, coffee, vani...    9   30     4.25
# 69   Maple, freshly roasted coffee, and blueberry a...    9  N/A     4.22
# 8    Breakfast Stout brewed with love, coffee and W...    9   30     4.16
# 157  Morning Timber's baby brother. This session-ab...  5.5  N/A     4.02
#
#     Number of ratings Date Added    IPA
# 63                722   04/03/19  False
# 69                665   05/25/19  False
# 8               2,124   04/04/18  False
# 157               246   01/22/20  False

# %%
Stout_Imperial_Double_Milk=beers[beers['Beer Type']=='Stout - Imperial / Double Milk']

# %%
Stout_Imperial_Double_Milk
# Out:
#      Unnamed: 0                          Beer Name  \
# 20           20                     Campfire Tales
# 9             9                   Neapolitan Shake
# 143         143    Super Scoop'd Cookies And Cream
# 128         128  Super Scoop'd Mint Chocolate Chip
# 140         140            Not My Gumdrop Buttons!
# 161         161                      Pineapple Pop
# 136         136                         Banana Pop
#
#                           Beer Type  \
# 20   Stout - Imperial / Double Milk
# 9    Stout - Imperial / Double Milk
# 143  Stout - Imperial / Double Milk
# 128  Stout - Imperial / Double Milk
# 140  Stout - Imperial / Double Milk
# 161  Stout - Imperial / Double Milk
# 136  Stout - Imperial / Double Milk
#
#                                            Description  ABV%   IBU  Rating  \
# 20   Imperial Milk Stout brewed with 1886 malted ba...   9.1  N/A     4.21
# 9    The first collaboration between Beer Tree Brew...    10   35     4.20
# ...

# %%
IPA_American=beers[beers['Beer Type']=='IPA - American']

# %%
IPA_American
# Out:
#      Unnamed: 0                  Beer Name       Beer Type  \
# 96           96              Super Pacific  IPA - American
# 210         210     Dre-Day West Coast IPA  IPA - American
# 233         233  Animal Style (Wet Hopped)  IPA - American
# 10           10               Animal Style  IPA - American
#
#                                            Description    ABV%   IBU  Rating  \
# 96   A delicious West Coast Style IPA dry hopped wi...  6.9021  N/A     3.90
# 210  Straight out the streets of Port Crane, Dre-Da...     5.9   65     3.87
# 233  A limited edition release of our classic IPA, ...     6.5  N/A     3.86
# 10   A privilege to some, a secret to most. West Co...     6.5  N/A     3.80
#
#     Number of ratings Date Added   IPA
# 96                488   06/10/21  True
# 210               115   06/27/18  True
# 233                59   09/25/20  True
# 10              1,929   03/02/19  True

# %%
Wheat_Beer_American_Pale_Wheat= beers[beers['Beer Type']=='Wheat Beer - American Pale Wheat']

# %%
Wheat_Beer_American_Pale_Wheat
# Out:
#     Unnamed: 0          Beer Name                         Beer Type  \
# 12          12  Raspberry Jammin'  Wheat Beer - American Pale Wheat
#
#                                           Description ABV%  IBU  Rating  \
# 12  Raspberry wheat ale brewed with NYS Craft Malt...  5.2  15     3.79
#
#    Number of ratings Date Added    IPA
# 12             1,645   03/09/18  False

# %%
Stout_Milk_Sweet=beers[beers['Beer Type']=='Stout - Milk / Sweet']

# %%
Stout_Milk_Sweet
# Out:
#      Unnamed: 0                                     Beer Name  \
# 165         165                     Fika - Chocolate, Coconut
# 13           13                                          Fika
# 236         236  Super Scoop'd Triple Chocolate Coconut Fudge
# 114         114                              Smashed Coconuts
# 134         134                                   Cocoa Beans
#
#                 Beer Type                                        Description  \
# 165  Stout - Milk / Sweet  Make time for Fika everyday! This sweet Milk s...
# 13   Stout - Milk / Sweet  Make time for Fika everyday! This sweet Milk s...
# 236  Stout - Milk / Sweet  Hop aboard, this is a one way ticket to Chocol...
# 114  Stout - Milk / Sweet  Silky smooth Milk Stout boasting a decadent ar...
# 134  Stout - Milk / Sweet  Brewed using specially roasted Dominican Cocoa...
#
#     ABV%   IBU  Rating Number of ratings Date Added    IPA
# 165  7.9  N/A     4.27               233   01/26/21  False
# ...

# %%
Pale_Ale_New_England_Hazy=beers[beers['Beer Type']=='Pale Ale - New England / Hazy']

# %%
Pale_Ale_New_England_Hazy
# Out:
#      Unnamed: 0                Beer Name                      Beer Type  \
# 95           95              Photosphere  Pale Ale - New England / Hazy
# 204         204     Cloudy Haze - Strata  Pale Ale - New England / Hazy
# 121         121          Find Your Oasis  Pale Ale - New England / Hazy
# 225         225     Cloudy Haze - Simcoe  Pale Ale - New England / Hazy
# 56           56              Discoveries  Pale Ale - New England / Hazy
# 216         216      Cloudy Haze - Citra  Pale Ale - New England / Hazy
# 148         148  Cloudy Haze - El Dorado  Pale Ale - New England / Hazy
# 15           15              Cloudy Haze  Pale Ale - New England / Hazy
# 228         228     Cloudy Haze - Riwaka  Pale Ale - New England / Hazy
# 61           61       Beer For My Ponies  Pale Ale - New England / Hazy
#
#                                            Description ABV%   IBU  Rating  \
# 95   Rounding out our Solar Series is Photosphere. ...  5.4  N/A     4.09
# ...

# %%
Stout_Russian_Imperial=beers[beers['Beer Type']=='Stout - Russian Imperial']

# %%
Stout_Russian_Imperial
# Out:
#     Unnamed: 0        Beer Name                 Beer Type  \
# 17          17  Finding Bigfoot  Stout - Russian Imperial
#
#                                           Description ABV%  IBU  Rating  \
# 17  An oh-so-smooth Russian imperial stout boastin...    9  45     3.97
#
#    Number of ratings Date Added    IPA
# 17             1,451   10/22/17  False

# %%
Sour_Berliner_Weisse=beers[beers['Beer Type']=='Sour - Berliner Weisse']

# %%
Sour_Berliner_Weisse
# Out:
#      Unnamed: 0                               Beer Name  \
# 200         200              Slightly Fuzzy Cherry Lime
# 105         105          Slightly Fuzzy Blackberry Lime
# 220         220           Slightly Fuzzy - Sweet Cherry
# 47           47           Slightly Fuzzy Blueberry Lime
# 19           19           Slightly Fuzzy Raspberry Lime
# 193         193   Staycation - Blueberry + Passionfruit
# 173         173  Slightly Fuzzy Strawberry Rhubarb Lime
# 53           53               Slightly Fuzzy Mango Lime
#
#                   Beer Type  \
# 200  Sour - Berliner Weisse
# 105  Sour - Berliner Weisse
# 220  Sour - Berliner Weisse
# 47   Sour - Berliner Weisse
# 19   Sour - Berliner Weisse
# 193  Sour - Berliner Weisse
# 173  Sour - Berliner Weisse
# 53   Sour - Berliner Weisse
#
#                                            Description ABV%   IBU  Rating  \
# 200                                            unknown  4.5  N/A     4.03
# ...

# %%
IPA_Imperial_Double=beers[beers['Beer Type']=='IPA - Imperial / Double']

# %%
IPA_Imperial_Double
# Out:
#     Unnamed: 0      Beer Name                Beer Type  \
# 24          24  Flying Upward  IPA - Imperial / Double
#
#                                           Description ABV%   IBU  Rating  \
# 24  Brewed with 2-Row, Flaked Oats, Flaked Wheat, ...  8.3  N/A     4.17
#
#    Number of ratings Date Added   IPA
# 24             1,338   06/01/19  True

# %%
Wheat_Beer_Hefeweizen=beers[beers['Beer Type']=='Wheat Beer - Hefeweizen']

# %%
Wheat_Beer_Hefeweizen
# Out:
#     Unnamed: 0  Beer Name                Beer Type  \
# 29          29  Hugh Hefe  Wheat Beer - Hefeweizen
#
#                                           Description ABV%  IBU  Rating  \
# 29  A NY-style Hefeweizen that the Playboy himself...  4.9  11     3.67
#
#    Number of ratings Date Added    IPA
# 29             1,237   10/29/17  False

# %%
IPA_Milkshake=beers[beers['Beer Type']=='IPA - Milkshake']

# %%
IPA_Milkshake
# Out:
#      Unnamed: 0                                          Beer Name  \
# 153         153           Feeling Cute - Strawberry, Peanut Butter
# 38           38                  Feeling Cute - Strawberry, Banana
# 215         215  Feeling Cute - Blackberry, Graham Cracker, Van...
#
#            Beer Type                                        Description ABV%  \
# 153  IPA - Milkshake  Milkshake IPA brewed with 2-row, wheat, oats a...  7.1
# 38   IPA - Milkshake  Milkshake IPA brewed with 2-row, wheat, oats a...  7.1
# 215  IPA - Milkshake  Milkshake IPA brewed with 2-row, wheat, oats a...  7.1
#
#       IBU  Rating Number of ratings Date Added   IPA
# 153  N/A     4.04               275   02/14/20  True
# 38   N/A     4.03             1,065   05/15/19  True
# 215  N/A     3.99               105   11/28/19  True

# %%
IPA_Triple_New_England_Hazy=beers[beers['Beer Type']=='IPA - Triple New England / Hazy']

# %%
IPA_Triple_New_England_Hazy
# Out:
#      Unnamed: 0                    Beer Name                        Beer Type  \
# 55           55               Leave No Trace  IPA - Triple New England / Hazy
# 50           50              Super Cat Daddy  IPA - Triple New England / Hazy
# 48           48  Triple Pineapple Creamsicle  IPA - Triple New England / Hazy
# 41           41                   Kitty King  IPA - Triple New England / Hazy
# 122         122                Desolate Peak  IPA - Triple New England / Hazy
# 86           86                    Command Z  IPA - Triple New England / Hazy
# 75           75                   Solar Apex  IPA - Triple New England / Hazy
# 162         162              Virtual Hangout  IPA - Triple New England / Hazy
# 98           98                  Lost Forest  IPA - Triple New England / Hazy
#
#                                            Description  ABV%   IBU  Rating  \
# 55   Clocking in at 10.2%, this TIPA is filled with...  10.2  N/A     4.32
# ...

# %%
Pumpkin_Yam_Beer=beers[beers['Beer Type']=='Pumpkin / Yam Beer']

# %%
Pumpkin_Yam_Beer
# Out:
#     Unnamed: 0         Beer Name           Beer Type  \
# 44          44  Mashing Pumpkins  Pumpkin / Yam Beer
#
#                                           Description ABV%  IBU  Rating  \
# 44  A sign of the times, a turn of the seasons! Ma...  5.6  11     3.84
#
#    Number of ratings Date Added    IPA
# 44               924   10/15/17  False

# %%
IPA_Session=beers[beers['Beer Type']=='IPA - Session']

# %%
IPA_Session
# Out:
#      Unnamed: 0      Beer Name      Beer Type  \
# 185         185   Citra Splash  IPA - Session
# 46           46  Craft All Day  IPA - Session
#
#                                            Description ABV%   IBU  Rating  \
# 185  Light, crisp, and highly drinkable Session IPA...  5.3  N/A     3.88
# 46   Wonderfully crafted session IPA that gives you...    5   35     3.73
#
#     Number of ratings Date Added   IPA
# 185               176   05/31/19  True
# 46                905   02/21/18  True

# %%
Porter_Imperial_Double=beers[beers['Beer Type']=='Porter - Imperial / Double']

# %%
Porter_Imperial_Double
# Out:
#     Unnamed: 0      Beer Name                   Beer Type  \
# 51          51  Lost Coconuts  Porter - Imperial / Double
#
#                                           Description  ABV%  IBU  Rating  \
# 51  Silky smooth Imperial Coconut Porter. Chocolat...  10.5  45     3.99
#
#    Number of ratings Date Added    IPA
# 51               842   02/13/18  False

# %%
IPA_Sour=beers[beers['Beer Type']=='IPA - Sour']

# %%
IPA_Sour
# Out:
#      Unnamed: 0                                          Beer Name  \
# 94           94     Trippy Tree - Pineapple, Pink Guava, Tangerine
# 77           77        Virtuosity - Cherry, Raspberry, Marshmallow
# 174         174  Virtuosity: Passion Fruit, Pineapple, Dragon F...
# 107         107                   Trippy Tree - Vanilla, Tangerine
# 89           89            Trippy Tree - Mango, Pineapple, Coconut
# 84           84      Virtuosity - Blood Orange, Mango, Marshmallow
# 221         221            Virtuosity - Boysenberry, Lemon, Almond
# 131         131        Trippy Tree - Passionfruit, Orange, Vanilla
# 115         115       Trippy Tree - Dragon Fruit, Mango, Raspberry
# 201         201                      Trippy Tree - Blueberry Mango
# 176         176   Trippy Tree - Boysenberry, Raspberry, Blackberry
# 93           93  Virtuosity - Passion Fruit, Dragon Fruit, Mars...
# 99           99                                    Euphoric Colors
# ...

# %%
beers['Beer Type'].unique()
# Out:
# array(['Stout - Imperial / Double', 'Sour - Fruited',
#        'IPA - Imperial / Double New England / Hazy', 'IPA - Sour',
#        'IPA - Triple New England / Hazy', 'Stout - Milk / Sweet',
#        'Stout - Coffee', 'IPA - New England / Hazy',
#        'Stout - Imperial / Double Milk',
#        'IPA - Imperial / Double Milkshake', 'IPA - Imperial / Double',
#        'Pale Ale - New England / Hazy', 'Sour - Other',
#        'Sour - Fruited Berliner Weisse', 'IPA - Milkshake',
#        'Sour - Berliner Weisse', 'Stout - American', 'Lager - American',
#        'Porter - Imperial / Double', 'Stout - Russian Imperial',
#        'Stout - White', 'Hard Seltzer', 'Fruit Beer', 'Pilsner - German',
#        'IPA - American', 'Farmhouse Ale - Saison', 'IPA - Session',
#        'Sour - Traditional Gose', 'Wheat Beer - Other', 'Pilsner - Other',
#        'Pumpkin / Yam Beer', 'Table Beer', 'Märzen',
#        'Wheat Beer - American Pale Wheat', 'Pale Ale - American',
# ...

# %%
Sour_Fruited=beers[beers['Beer Type']== 'Sour - Fruited']

# %%
Sour_Fruited
# Out:
#      Unnamed: 0                                          Beer Name  \
# 129         129                                     Trippy Tropics
# 199         199          Trippy Snake - Pineapple, Coconut, Ginger
# 180         180                             Layered - Key Lime Pie
# 68           68  Hyper Swirl: Dragon Fruit, Mango, Strawberry, ...
# 85           85  Trippy Tree - Blueberry, Graham Cracker, Marsh...
# 154         154                    Layered - Strawberry Cheesecake
# 179         179         Trippy Tree - Chamomile, Strawberry, Honey
# 137         137                                      Crypto Cookie
# 78           78                                Pollinated Paradise
# 144         144  Ripened - Dragonfruit + Passion Fruit + Pink G...
# 189         189  Hyper Swirl: Passion Fruit, Raspberry, Mango, ...
# 232         232                            Orange Vanilla Cardamom
# 97           97  Layered - Strawberry, Blueberry, Vanilla, Granola
# ...

# %%
Cream_Ale=beers[beers['Beer Type']=='Cream Ale']

# %%
Cream_Ale
# Out:
#      Unnamed: 0         Beer Name  Beer Type  \
# 108         108        Tree Light  Cream Ale
# 127         127  Tree Ultra Light  Cream Ale
#
#                                            Description ABV%  IBU  Rating  \
# 108  Mild, light bodied Ale with a subtle presence ...  4.2  15     3.47
# 127  A super session-able light cream ale. Our gent...    4  13     3.41
#
#     Number of ratings Date Added    IPA
# 108               443   10/09/17  False
# 127               358   12/14/17  False

# %%
Sour_Fruited_Berliner_Weisse=beers[beers['Beer Type']=='Sour - Fruited Berliner Weisse']

# %%
Sour_Fruited_Berliner_Weisse
# Out:
#      Unnamed: 0                                  Beer Name  \
# 112         112   Slightly Fuzzy Dragon Fruit, Mango, Lime
# 227         227      Slightly Fuzzy Blueberry, Mango, Lime
# 171         171  Slightly Fuzzy Watermelon, Cucumber, Lime
# 229         229       Slightly Fuzzy Blueberry, Acai, Lime
#
#                           Beer Type  \
# 112  Sour - Fruited Berliner Weisse
# 227  Sour - Fruited Berliner Weisse
# 171  Sour - Fruited Berliner Weisse
# 229  Sour - Fruited Berliner Weisse
#
#                                            Description ABV%   IBU  Rating  \
# 112  Mixed Fermentation Ale conditioned on loads of...  4.5  N/A     4.06
# 227  Mixed fermentation ale conditioned on blueberr...  4.5  N/A     3.92
# 171  Mixed fermentation ale conditioned on cucumber...  4.5  N/A     3.71
# 229                                            unknown  4.5  N/A     3.69
#
#     Number of ratings Date Added    IPA
# 112               422   04/09/21  False
# ...

# %%
Stout_Imperial_Double=beers[beers['Beer Type']=='Stout - Imperial / Double']

# %%
Stout_Imperial_Double
# Out:
#      Unnamed: 0                                   Beer Name  \
# 243         243                Bourbon Barrel Aged Deadfall
# 172         172          Bourbon Barrel Aged Morning Timber
# 242         242     Bourbon Barrel Aged Stout With Cherries
# 198         198              Last Course - Maple, Pecan Pie
# 142         142  Deadfall - Vanilla, Chocolate, Pumpkin Pie
# 207         207                            Deadfall - Pecan
# 120         120                             Nutty Professor
# 160         160                          Black Is Beautiful
# 113         113                                    Deadfall
# 132         132                               Santa's Serum
#
#                      Beer Type  \
# 243  Stout - Imperial / Double
# 172  Stout - Imperial / Double
# 242  Stout - Imperial / Double
# 198  Stout - Imperial / Double
# 142  Stout - Imperial / Double
# 207  Stout - Imperial / Double
# 120  Stout - Imperial / Double
# 160  Stout - Imperial / Double
# ...

# %%
Sour_Other=beers[beers['Beer Type']=='Sour - Other']

# %%
Sour_Other
# Out:
#      Unnamed: 0      Beer Name     Beer Type  \
# 163         163  Funky Berries  Sour - Other
# 116         116     PM Express  Sour - Other
#
#                                            Description ABV%   IBU  Rating  \
# 163  Fruited Sour NEIPA fremented with Blackberries...  7.2  N/A     4.06
# 116  Heavy Mango, Pineapple taste and aroma with a ...  5.3   11     3.87
#
#     Number of ratings Date Added    IPA
# 163               239   11/08/18  False
# 116               372   08/15/18  False

# %%
Pilsner_Other=beers[beers['Beer Type']=='Pilsner - Other']

# %%
Pilsner_Other
# Out:
#      Unnamed: 0    Beer Name        Beer Type  \
# 123         123  Crisp Trees  Pilsner - Other
#
#                                            Description ABV%   IBU  Rating  \
# 123  Introducing our very first Pilsner. Crisp like...  4.5  N/A     3.84
#
#     Number of ratings Date Added    IPA
# 123               373   11/02/20  False

# %%
Pilsner_German=beers[beers['Beer Type']=='Pilsner - German']

# %%
Pilsner_German
# Out:
#      Unnamed: 0    Beer Name         Beer Type  \
# 146         146  Hallo! Pils  Pilsner - German
#
#                                            Description ABV%   IBU  Rating  \
# 146  This German style Pilsner is ideal for a summe...  4.5  N/A     3.91
#
#     Number of ratings Date Added    IPA
# 146               288   06/15/21  False

# %%
Märzen=beers[beers['Beer Type']=='Märzen']

# %%
Märzen
# Out:
#      Unnamed: 0    Beer Name Beer Type  \
# 147         147  Oktoberfest    Märzen
#
#                                            Description ABV%   IBU  Rating  \
# 147  A cool breeze sends prickly goosebumps atop yo...  5.4  N/A      3.8
#
#     Number of ratings Date Added    IPA
# 147               288   09/09/21  False

# %%
Lager_American=beers[beers['Beer Type']=='Lager - American']

# %%
Lager_American
# Out:
#      Unnamed: 0                          Beer Name         Beer Type  \
# 223         223  Stave Series I: Foeder Aged Lager  Lager - American
# 150         150                        Boat Launch  Lager - American
#
#                                            Description ABV%   IBU  Rating  \
# 223  Up first in our Stave Series: A Foeder aged la...  4.5  N/A     4.00
# 150  Introducing Boat Launch, the official beer of ...    5  N/A     3.82
#
#     Number of ratings Date Added    IPA
# 223                89   10/21/21  False
# 150               292   07/27/21  False

# %%
Farmhouse_Ale_Saison=beers[beers['Beer Type']=='Farmhouse Ale - Saison']

# %%
Farmhouse_Ale_Saison
# Out:
#      Unnamed: 0           Beer Name               Beer Type  \
# 222         222  Staycation - Mango  Farmhouse Ale - Saison
# 168         168  Staycation - Guava  Farmhouse Ale - Saison
#
#                                            Description ABV%   IBU  Rating  \
# 222  Part 2 of the Staycation series - Slightly tar...  5.4  N/A     3.90
# 168  Slightly tart, session-able, farmhouse ale bre...  5.4   11     3.73
#
#     Number of ratings Date Added    IPA
# 222                94   07/04/18  False
# 168               221   05/26/18  False

# %%
Fruit_Beer=beers[beers['Beer Type']=='Fruit Beer']

# %%
Fruit_Beer
# Out:
#      Unnamed: 0 Beer Name   Beer Type  \
# 170         170   Juicy J  Fruit Beer
#
#                                            Description ABV%  IBU  Rating  \
# 170  Heavy additions of Tangerine and Soursop give ...  7.1  35     3.93
#
#     Number of ratings Date Added    IPA
# 170               211   01/17/18  False

# %%
Stout_White=beers[beers['Beer Type']=='Stout - White']

# %%
Stout_White
# Out:
#      Unnamed: 0     Beer Name      Beer Type  \
# 182         182  Comfort Zone  Stout - White
#
#                                            Description ABV%   IBU  Rating  \
# 182  Pumpkin Spice Chai Latte, Blonde Stout. Brewed...  7.3  N/A     3.93
#
#     Number of ratings Date Added    IPA
# 182               193   10/11/19  False

# %%
Lager_American_Light=beers[beers['Beer Type']=='Lager - American Light']

# %%
Lager_American_Light
# Out:
#      Unnamed: 0                  Beer Name               Beer Type  \
# 206         206  We Came We Saw We Lagered  Lager - American Light
#
#                                            Description  ABV%  IBU  Rating  \
# 206  An American Lager brewed with 100% NYS ingredi...  4.75  13     3.69
#
#     Number of ratings Date Added    IPA
# 206               128   08/18/18  False

# %%
Stout_American=beers[beers['Beer Type']=='Stout - American']

# %%
Stout_American
# Out:
#      Unnamed: 0      Beer Name         Beer Type  \
# 208         208  Cocoa Mi Loco  Stout - American
#
#                                            Description ABV%  IBU  Rating  \
# 208  Deranged notes of cocoa carried by pure Madaga...  7.9  40     4.02
#
#     Number of ratings Date Added    IPA
# 208               127   07/27/18  False

# %%
Wheat_Beer_Other=beers[beers['Beer Type']=='Wheat Beer - Other']

# %%
Wheat_Beer_Other
# Out:
#      Unnamed: 0                  Beer Name           Beer Type  \
# 211         211  Raspberry & Peach Jammin'  Wheat Beer - Other
#
#                                            Description ABV%  IBU  Rating  \
# 211  Raspberry and Peach wheat ale brewed with 1886...  5.2  15     3.85
#
#     Number of ratings Date Added    IPA
# 211               108   02/11/18  False

# %%
Pale_Ale_American=beers[beers['Beer Type']=='Pale Ale - American']

# %%
Pale_Ale_American
# Out:
#      Unnamed: 0 Beer Name            Beer Type  \
# 217         217     Crush  Pale Ale - American
#
#                                            Description ABV%  IBU  Rating  \
# 217  Mosaic dry hopped, smooth, easy drinking Pale ...  5.8  30     3.78
#
#     Number of ratings Date Added    IPA
# 217               102   01/31/18  False

# %%
Table_Beer=beers[beers['Beer Type']=='Table Beer']

# %%
Table_Beer
# Out:
#      Unnamed: 0     Beer Name   Beer Type  \
# 219         219  Scoby Snacks  Table Beer
#
#                                            Description ABV%   IBU  Rating  \
# 219  Ale Brewed with Raspberry, Lemon and kombucha ...  3.5  N/A     3.83
#
#     Number of ratings Date Added    IPA
# 219                88   01/14/19  False

# %%
Hard_Seltzer=beers[beers['Beer Type']=='Hard Seltzer']

# %%
Hard_Seltzer
# Out:
#      Unnamed: 0                                 Beer Name     Beer Type  \
# 241         241                           Pure Tree Mango  Hard Seltzer
# 239         239                Pure Tree - Tropical Blend  Hard Seltzer
# 240         240  Pure Tree - Cherry, Lime, Blue Raspberry  Hard Seltzer
# 234         234   Pure Tree - Passionfruit, Orange, Guava  Hard Seltzer
# 230         230                   Pure Tree - Fruit Punch  Hard Seltzer
# 237         237           Pure Tree - Strawberry Lemonade  Hard Seltzer
#
#                                            Description ABV%   IBU  Rating  \
# 241                                            unknown  4.2  N/A     3.93
# 239  All natural hard seltzer made with a blend of ...  4.2  N/A     3.90
# 240  All natural hard seltzer made with cherry, lim...  4.2  N/A     3.86
# 234  All natural hard seltzer made with pure passio...  4.2  N/A     3.85
# 230  All natural Hard Seltzer made with a blend of ...  4.2  N/A     3.84
# ...

# %%
Blonde_Ale=beers[beers['Beer Type']=='Blonde Ale']

# %%
Blonde_Ale
# Out:
#      Unnamed: 0         Beer Name   Beer Type  \
# 231         231  Backwoods Blonde  Blonde Ale
#
#                                            Description ABV%  IBU  Rating  \
# 231  Sweet aroma with a mild hop bite, just how a b...  4.5  30     3.69
#
#     Number of ratings Date Added    IPA
# 231                58   02/28/18  False

# %%
Sour_Traditional_Gose=beers[beers['Beer Type']=='Sour - Traditional Gose']

# %%
Sour_Traditional_Gose
# Out:
#      Unnamed: 0       Beer Name                Beer Type Description ABV%  \
# 235         235  West Gose East  Sour - Traditional Gose     unknown  6.5
#
#       IBU  Rating Number of ratings Date Added    IPA
# 235  N/A     3.86                38   04/14/21  False

# %%
beers=beers.sort_values(by="Rating", ascending=False)

# %%
beers
# Out:
#      Unnamed: 0                                       Beer Name  \
# 243         243                    Bourbon Barrel Aged Deadfall
# 129         129                                  Trippy Tropics
# 172         172              Bourbon Barrel Aged Morning Timber
# 124         124                Roots & Trees & Friends & Things
# 94           94  Trippy Tree - Pineapple, Pink Guava, Tangerine
# ..          ...                                             ...
# 231         231                                Backwoods Blonde
# 206         206                       We Came We Saw We Lagered
# 29           29                                       Hugh Hefe
# 108         108                                      Tree Light
# 127         127                                Tree Ultra Light
#
#                                       Beer Type  \
# 243                   Stout - Imperial / Double
# 129                              Sour - Fruited
# 172                   Stout - Imperial / Double
# ...

# %%
no_na=pd.read_csv("No_Missing_Beer_Tree_Untappd.csv")

# %%
no_na
# Out:
#      Unnamed: 0                                 Beer Name  \
# 0             0               Double Pineapple Creamsicle
# 1             1                             Velcrow Walls
# 2             2                      Pineapple Creamsicle
# 3             3                               Citra Grove
# 4             4                           Into the Forest
# ..          ...                                       ...
# 239         239                Pure Tree - Tropical Blend
# 240         240  Pure Tree - Cherry, Lime, Blue Raspberry
# 241         241                           Pure Tree Mango
# 242         242   Bourbon Barrel Aged Stout With Cherries
# 243         243              Bourbon Barrel Aged Deadfall
#
#                                       Beer Type  \
# 0             IPA - Imperial / Double Milkshake
# 1                      IPA - New England / Hazy
# 2                      IPA - New England / Hazy
# 3                      IPA - New England / Hazy
# ...

# %%
no_na=no_na.sort_values(by="Rating", ascending=False)

# %%
no_na
# Out:
#      Unnamed: 0                                       Beer Name  \
# 243         243                    Bourbon Barrel Aged Deadfall
# 129         129                                  Trippy Tropics
# 172         172              Bourbon Barrel Aged Morning Timber
# 124         124                Roots & Trees & Friends & Things
# 94           94  Trippy Tree - Pineapple, Pink Guava, Tangerine
# ..          ...                                             ...
# 231         231                                Backwoods Blonde
# 206         206                       We Came We Saw We Lagered
# 29           29                                       Hugh Hefe
# 108         108                                      Tree Light
# 127         127                                Tree Ultra Light
#
#                                       Beer Type  \
# 243                   Stout - Imperial / Double
# 129                              Sour - Fruited
# 172                   Stout - Imperial / Double
# ...

# %%
no_na=no_na[no_na["ABV%"].str.contains("N/")==False]

# %%
no_na["Rating"] = pd.to_numeric(no_na["Rating"])
no_na["ABV%"] = pd.to_numeric(no_na["ABV%"])
no_na["Number of ratings"] = (no_na["Number of ratings"].str.split()).apply(lambda x: float(x[0].replace(',', '')))
#no_na["Number of ratings"] = pd.to_numeric(no_na["Number of ratings"])
# Out:
# <ipython-input-204-a2bb98b3c2f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_na["Rating"] = pd.to_numeric(no_na["Rating"])
# <ipython-input-204-a2bb98b3c2f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_na["ABV%"] = pd.to_numeric(no_na["ABV%"])
# <ipython-input-204-a2bb98b3c2f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
no_na.dtypes
# Out:
# Unnamed: 0             int64
# Beer Name             object
# Beer Type             object
# Description           object
# ABV%                 float64
# IBU                   object
# Rating               float64
# Number of ratings    float64
# Date Added            object
# IPA                     bool
# dtype: object

# %%
plt.scatter(x=no_na['ABV%'], y=no_na['Rating'], alpha=0.3)
plt.xlabel("Alcohol Percentage")
plt.ylabel("Rating")
plt.title("Alcohol Percentage vs. Ratings ")
# Out:
# Text(0.5, 1.0, 'Alcohol Percentage vs. Ratings ')

# %% [markdown]
# ## Beer Type analysis

# %%
Sour_Fruited=no_na[no_na['Beer Type']== 'Sour - Fruited']

# %%
IPA_Sour=no_na[no_na['Beer Type']=='IPA - Sour']

# %%
IPA_Triple_New_England_Hazy=no_na[no_na['Beer Type']=='IPA - Triple New England / Hazy']

# %%
IPA_Imperial_Double_New_England_Hazy=no_na[no_na['Beer Type']=='IPA - Imperial / Double New England / Hazy']

# %%
plt.scatter(x=Sour_Fruited['ABV%'], y=Sour_Fruited['Rating'], alpha=0.3)
plt.xlabel("Alcohol Percentage")
plt.ylabel("Rating")
plt.title("Sour_Fruited Alcohol Percentage vs. Ratings ")
# Out:
# Text(0.5, 1.0, 'Sour_Fruited Alcohol Percentage vs. Ratings ')

# %%
plt.scatter(x=IPA_Sour['ABV%'], y=IPA_Sour['Rating'], alpha=0.3)
plt.xlabel("Alcohol Percentage")
plt.ylabel("Rating")
plt.title("IPA_Sour Alcohol Percentage vs. Ratings ")
# Out:
# Text(0.5, 1.0, 'IPA_Sour Alcohol Percentage vs. Ratings ')

# %%
plt.scatter(x=IPA_Triple_New_England_Hazy['ABV%'], y=IPA_Triple_New_England_Hazy['Rating'], alpha=0.3)
plt.xlabel("Alcohol Percentage")
plt.ylabel("Rating")
plt.title("IPA_Triple_New_England_Hazy Alcohol Percentage vs. Ratings ")
# Out:
# Text(0.5, 1.0, 'IPA_Triple_New_England_Hazy Alcohol Percentage vs. Ratings ')

# %%
plt.scatter(x=IPA_Imperial_Double_New_England_Hazy['ABV%'], y=IPA_Imperial_Double_New_England_Hazy['Rating'], alpha=0.3)
plt.xlabel("Alcohol Percentage")


plt.ylabel("Rating")
plt.title("IPA_Imperial_Double_New_England_Hazy Alcohol Percentage vs. Ratings ")
# Out:
# Text(0.5, 1.0, 'IPA_Imperial_Double_New_England_Hazy Alcohol Percentage vs. Ratings ')

# %%
plt.scatter(y=no_na['Rating'], x=no_na['Number of ratings'], alpha=0.3)
plt.xlabel("Number of ratings")


plt.ylabel("Rating")


plt.title("Number of ratings vs. Ratings ")
# Out:
# Text(0.5, 1.0, 'Number of ratings vs. Ratings ')

# %%
thousand=no_na[no_na['Number of ratings']>=1000]

# %%
#thousand=thousand[thousand['Number of ratings']>=1000]

# %%
thousand
# Out:
#     Unnamed: 0                          Beer Name  \
# 41          41                         Kitty King
# 35          35                        Carbon Flux
# 30          30                      Over Exposure
# 13          13                               Fika
# 43          43                        High Summit
# 32          32                       Chromosphere
# 20          20                     Campfire Tales
# 9            9                   Neapolitan Shake
# 5            5                         Brain Stew
# 0            0        Double Pineapple Creamsicle
# 14          14                  Edge of the Earth
# 26          26                          Clickbait
# 27          27                            Skyline
# 42          42                    Perplexed Lines
# 21          21                    Pure Intentions
# 24          24                      Flying Upward
# 11          11                    Time To Pretend
# 16          16                          Cultivate
# ...

# %%
plt.scatter(x=thousand['ABV%'], y=thousand['Rating'], alpha=0.4)
plt.xlabel("Alcohol Percentage")
plt.ylabel("Rating")
z = np.polyfit(thousand['ABV%'], thousand['Rating'], 1)
p = np.poly1d(z)
plt.plot(thousand['ABV%'],p(thousand['ABV%']),"r--")

plt.title("Alcohol Percentage vs. Ratings for all beers with over 1000 reviews ")
# Out:
# Text(0.5, 1.0, 'Alcohol Percentage vs. Ratings for all beers with over 1000 reviews ')
